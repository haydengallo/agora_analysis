# %%
### Hayden Gallo 
### Bucci Lab
### 6/26/24
### Analyzing Cobratoolbox/Agora2 Output

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import os

# %%
os.chdir('/Users/haydengallo/Documents/Bucci_Lab/cobratoolbox_analysis/agora_term_preterm_data/')
print(os.getcwd())
# Out:
# /Users/haydengallo/Documents/Bucci_Lab/cobratoolbox_analysis/agora_term_preterm_data

# %%
sec_flux_sig = pd.read_csv('/Users/haydengallo/Documents/Bucci_Lab/cobratoolbox_analysis/agora_term_preterm_data/Results/Statistics/inputDiet_net_secretion_fluxes_Group_SignificantFeatures.txt', sep ="\t")
upt_flux_sig = pd.read_csv('./Results/Statistics/inputDiet_net_uptake_fluxes_Group_SignificantFeatures.txt', sep="\t")
sub_sys_abun_sig = pd.read_csv('./Results/Statistics/SubsystemAbundance_Group_SignificantFeatures.txt', sep ='\t')
rxn_pres_sig = pd.read_csv('./Results/Statistics/ReactionPresence_Group_SignificantFeatures.txt', sep = '\t')
rxn_abun_sig = pd.read_csv('./Results/Statistics/ReactionAbundance_Group_SignificantFeatures.txt', sep='\t')

# %%
rxn_abun_sig.head()
# Out:
#       Averages  X17FM0050301  X17FM0050501  X17FM0057101  X17FM0063301  \
# 0  10DMMCNFDOR      0.090500      0.000000      0.000000      0.000000
# 1     12PPDSDH      0.467845      0.071400      0.640693      0.152382
# 2   12PPD_Stex      0.467097      0.360323      0.686745      0.137160
# 3     12PPDtpp      0.467097      0.360323      0.686745      0.137160
# 4       13PPDH      0.090500      0.000000      0.000000      0.000000
#
#    X17FM0064301  X17FM0066001  X17FM0071801  X17FM0073801  X17FM0075201  ...  \
# 0      0.010994      0.000000      0.009433      0.000892      0.056694  ...
# 1      0.146391      0.281027      0.013562      0.186490      0.306063  ...
# 2      0.253227      0.561899      0.280336      0.230590      0.514882  ...
# 3      0.253227      0.561899      0.280336      0.230590      0.514882  ...
# 4      0.010994      0.000000      0.009433      0.000892      0.056694  ...
#
#    X17FM0195101  X17FM0195601  X17FM0196401  X17FM0200101  X17FM0203701  \
# ...
